# %%
import pandas as pd
from data_extraction import DataExtractor
from database_utils import DatabaseConnector

db = DatabaseConnector()
engine = db.init_db_engine()
PI_KEY = 'yFBQbwXe9J3sd6zWVAMrK6lcxxr0q1lr2PT6DDMX'
df = DataExtractor.read_rds_table("orders_table",engine)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 8
#       6 engine = db.init_db_engine()
#       7 PI_KEY = 'yFBQbwXe9J3sd6zWVAMrK6lcxxr0q1lr2PT6DDMX'
# ----> 8 df = DataExtractor.read_rds_table("orders_table",engine)
#       9 df
#
# File ~/Multinational-Retail-Data/Multinational-Retail-Data/Multinational-Retail-Data/data_extraction.py:19, in read_rds_table(self, table_name)
#      17 self.engine.connect()
#      18 user_data = pd.read_sql_table(table_name, engine)
# ---> 19 return user_data
#
# AttributeError: 'str' object has no attribute 'rds_database'

# %%
from database_utils import DatabaseConnector
connector = DatabaseConnector()
df = connector.list_db_tables()
print(df)
# Out:
# ['legacy_store_details', 'legacy_users', 'orders_table']

# %%
from database_utils import DatabaseConnector
from data_extraction import DataExtractor
from data_cleaning import DataCleaning

# Create instances for each class
db_connector = DatabaseConnector()
data_extractor = DataExtractor()
data_cleaning = DataCleaning()


# Retrieve the name of the table that contains user data
tables_list = db_connector.list_db_tables()
print(tables_list)

# Extract and read user data from the database
user_data = data_extractor.read_rds_table("legacy_users")

# Perform the cleaning of user data
# user_data = data_cleaning.clean_user_data(user_data)

# Use the method to upload user data in the database
# db_connector.upload_to_db(user_data)
# Out:
# ['legacy_store_details', 'legacy_users', 'orders_table']

# %%
user_data.head()
# Out:
#    index first_name last_name date_of_birth                    company  \
# 0      0   Sigfried     Noack    1990-09-30         Heydrich Junitz KG
# 1      1        Guy     Allen    1940-12-01                    Fox Ltd
# 2      2      Harry  Lawrence    1995-08-02  Johnson, Jones and Harris
# 3      3     Darren   Hussain    1972-09-23                Wheeler LLC
# 4      4      Garry     Stone    1952-12-20                 Warner Inc
#
#                   email_address  \
# 0             rudi79@winkler.de
# 1  rhodesclifford@henderson.com
# 2  glen98@bryant-marshall.co.uk
# 3    daniellebryan@thompson.org
# 4       billy14@long-warren.com
#
#                                              address         country  \
# 0                       Zimmerstr. 1/0\n59015 Gießen         Germany
# 1  Studio 22a\nLynne terrace\nMcCarthymouth\nTF0 9GH  United Kingdom
# 2                 92 Ann drive\nJoanborough\nSK0 6LR  United Kingdom
# ...

# %%
user_data.drop(0)

# %%
user_data.tail()
# Out:
#        index first_name last_name date_of_birth                       company  \
# 15315  14913    Stephen   Jenkins    1943-08-09  Thornton, Carroll and Newman
# 15316  14994    Stephen     Smith    1948-08-20               Robinson-Harris
# 15317  15012    Stephen  Losekann    1940-10-09                       Rosenow
# 15318  15269    Stephen    Rivera    1952-06-04         Taylor, Fry and Jones
# 15319   1249    Stephen    Duncan    1994-03-27    Phillips, Brown and Powell
#
#               email_address  \
# 15315   s.jenkins@smith.com
# 15316     s.smith@smith.com
# 15317  s.losekann@smith.com
# 15318    s.rivera@smith.com
# 15319    s.duncan@smith.com
#
#                                                  address         country  \
# 15315     Studio 41I\nJones lodge\nOliviaborough\nE8 3DU  United Kingdom
# 15316              530 Young parkway\nMillsfurt\nL4G 7NX  United Kingdom
# 15317  Viviane-Fritsch-Straße 3/5\n15064 Bad Liebenwerda         Germany
# ...

# %%
user_data.info
# Out:
# <bound method DataFrame.info of        index first_name last_name date_of_birth                       company  \
# 0          0   Sigfried     Noack    1990-09-30            Heydrich Junitz KG
# 1          1        Guy     Allen    1940-12-01                       Fox Ltd
# 2          2      Harry  Lawrence    1995-08-02     Johnson, Jones and Harris
# 3          3     Darren   Hussain    1972-09-23                   Wheeler LLC
# 4          4      Garry     Stone    1952-12-20                    Warner Inc
# ...      ...        ...       ...           ...                           ...
# 15315  14913    Stephen   Jenkins    1943-08-09  Thornton, Carroll and Newman
# 15316  14994    Stephen     Smith    1948-08-20               Robinson-Harris
# 15317  15012    Stephen  Losekann    1940-10-09                       Rosenow
# 15318  15269    Stephen    Rivera    1952-06-04         Taylor, Fry and Jones
# 15319   1249    Stephen    Duncan    1994-03-27    Phillips, Brown and Powell
#
# ...

# %%
print(user_data)
# Out:
#        index first_name last_name date_of_birth                       company  \
# 0          0   Sigfried     Noack    1990-09-30            Heydrich Junitz KG
# 1          1        Guy     Allen    1940-12-01                       Fox Ltd
# 2          2      Harry  Lawrence    1995-08-02     Johnson, Jones and Harris
# 3          3     Darren   Hussain    1972-09-23                   Wheeler LLC
# 4          4      Garry     Stone    1952-12-20                    Warner Inc
# ...      ...        ...       ...           ...                           ...
# 15315  14913    Stephen   Jenkins    1943-08-09  Thornton, Carroll and Newman
# 15316  14994    Stephen     Smith    1948-08-20               Robinson-Harris
# 15317  15012    Stephen  Losekann    1940-10-09                       Rosenow
# 15318  15269    Stephen    Rivera    1952-06-04         Taylor, Fry and Jones
# 15319   1249    Stephen    Duncan    1994-03-27    Phillips, Brown and Powell
#
# ...

# %%
user_data.display.max_row
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 user_data.display.max_row
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'display'

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print (df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 with pd.option_context('display.max_rows', None, 'display.max_columns', None):
# ----> 2     print (df)
#
# NameError: name 'df' is not defined
